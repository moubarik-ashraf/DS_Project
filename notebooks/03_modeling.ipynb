# %%
import os

# --- CONFIGURATION (REMPLIS ÇA) ---
GIT_USER = "moubarik-ashraf"
GIT_EMAIL = "moubarikashraf@gmail.com"
TOKEN = "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" # Ton Personal Access Token
REPO_NAME = "DS_Project" # Le nom exact du repo créé à l'étape 1

# --- 1. CRÉATION DE L'ARBORESCENCE LOCALE ---
project_structure = [
    "data/raw",
    "data/processed",
    "notebooks",
    "models",
    "src",
    "reports"
]

print("📁 Création des dossiers...")
for folder in project_structure:
    os.makedirs(folder, exist_ok=True)
    # On ajoute un fichier caché .gitkeep pour que Git accepte de suivre les dossiers vides
    with open(f"{folder}/.gitkeep", "w") as f:
        f.write("")

# --- 2. CRÉATION DES FICHIERS DE BASE ---
print("📄 Création des fichiers...")

# README.md
readme_content = f"""# {REPO_NAME}
Projet de classification (Data Science).

## Structure
- `data/` : Données brutes et traitées
- `notebooks/` : Analyses et modélisation
- `models/` : Modèles entraînés (.pkl)
- `src/` : Scripts Python
"""
with open("README.md", "w") as f:
    f.write(readme_content)

# .gitignore (Pour ignorer les fichiers inutiles)
gitignore_content = """
# Fichiers Colab et Jupyter
.ipynb_checkpoints
*/.ipynb_checkpoints/*

# Données temporaires ou lourdes (si jamais tu changes d'avis)
__pycache__/
*.pyc
"""
with open(".gitignore", "w") as f:
    f.write(gitignore_content)

# requirements.txt
with open("requirements.txt", "w") as f:
    f.write("pandas\nnumpy\nscikit-learn\nmatplotlib\nseaborn")

# --- 3. ENVOI SUR GITHUB (GIT PUSH) ---
print("🚀 Envoi vers GitHub...")

# Configuration de l'identité Git
# !git config --global user.email "$GIT_EMAIL"
# !git config --global user.name "$GIT_USER"

# Initialisation et Push
# !git init
# !git add .
# !git commit -m "Initialisation automatique de la structure du projet"
# !git branch -M main
# On ajoute l'URL avec le token pour l'authentification
# !git remote add origin https://{TOKEN}@github.com/{GIT_USER}/{REPO_NAME}.git
# !git push -u origin main

print(f"\n✅ Terminé ! Tout est en ligne ici : https://github.com/{GIT_USER}/{REPO_NAME}")
# Out:
# 📁 Création des dossiers...
# 📄 Création des fichiers...
# 🚀 Envoi vers GitHub...
# Reinitialized existing Git repository in /content/.git/
# On branch main
# nothing to commit, working tree clean
# error: remote origin already exists.
# remote: Write access to repository not granted.
# fatal: unable to access 'https://github.com/moubarik-ashraf/DS_Project.git/': The requested URL returned error: 403
#
# ✅ Terminé ! Tout est en ligne ici : https://github.com/moubarik-ashraf/DS_Project

# %%
import os



# --- DIAGNOSTIC ---
print("1. Vérification du dossier actuel...")
print(f"Dossier actuel : {os.getcwd()}")

# On vérifie si on est bien dans le dossier du projet
if not os.getcwd().endswith(REPO_NAME):
    try:
        os.chdir(REPO_NAME)
        print(f"Correction : Déplacement vers {REPO_NAME}")
    except:
        print(f"ERREUR : Le dossier {REPO_NAME} n'existe pas ici. As-tu lancé la première cellule ?")

print("\n2. État des fichiers (Git Status)...")
# !git status

print("\n3. Tentative de correction et d'envoi...")
# On ajoute tout ce qui traîne
# !git add .
# On fait un commit (si rien n'avait été commité)
# !git commit -m "Tentative de push de correction"

# On force l'URL d'origine avec le token pour être sûr
# !git remote remove origin
# !git remote add origin https://{TOKEN}@github.com/{GIT_USER}/{REPO_NAME}.git

# On pousse et ON REGARDE L'ERREUR si ça plante
print("\n4. Envoi vers GitHub (regarde le message ci-dessous) :")
# !git push -u origin main
# Out:
# 1. Vérification du dossier actuel...
# Dossier actuel : /content
# ERREUR : Le dossier DS_Project n'existe pas ici. As-tu lancé la première cellule ?
#
# 2. État des fichiers (Git Status)...
# On branch main
# nothing to commit, working tree clean
#
# 3. Tentative de correction et d'envoi...
# On branch main
# nothing to commit, working tree clean
#
# 4. Envoi vers GitHub (regarde le message ci-dessous) :
# remote: Write access to repository not granted.
# fatal: unable to access 'https://github.com/moubarik-ashraf/DS_Project.git/': The requested URL returned error: 403
